# %% [markdown]
# # 1. Dice rolls

# %%
import random as rnd

dice_rolls = []

for i in range(10):
    dice_rolls.append(rnd.randint(1,6))

print(f"Dice rolls : {dice_rolls}")

dice_rolls.sort()
print(f"Dice rolls in ascending order: {dice_rolls}")

dice_rolls.sort(reverse=True)
print(f"Dice rolls in descending order: {dice_rolls}")

print(f'Max value: {dice_rolls[0]}')
print(f'Min value: {dice_rolls[-1]}')
# Out:
# Dice rolls : [2, 5, 5, 3, 1, 3, 2, 4, 3, 2]
# Dice rolls in ascending order: [1, 2, 2, 2, 3, 3, 3, 4, 5, 5]
# Dice rolls in descending order: [5, 5, 4, 3, 3, 3, 2, 2, 2, 1]
# Max value: 5
# Min value: 1

# %% [markdown]
# # 2. Food Menu

# %%
food = ["vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor"]
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

for i in range(5):
    print(f'{weekdays[i]}: {food[i]}')
# Out:
# Monday: vegetarisk lasagne
# Tuesday: spaghetti
# Wednesday: fisk
# Thursday: grönsakssoppa
# Friday: pannkakor

# %% [markdown]
# # 3. Squares

# %%
import matplotlib.pyplot as plt

numbers = [x for x in range(21)]
squares = [x**2 for x in range(21)]

plt.plot(range(21), squares, "o-")
plt.xlabel("Numbers")
plt.ylabel("Squares")
plt.grid()

# %% [markdown]
# # 4. Chessboard

# %%
chess_letters = (f'ABCDEFGH')
chess_numbers = (f'12345678')
chess_list = [[letter+number for letter in chess_letters] for number in chess_numbers]

for row in chess_list:
    print(row)
# Out:
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']
# ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']
# ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']
# ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']
# ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']
# ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']
# ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']

# %% [markdown]
# # 5. Dice rolls convergence

# %%
import random as rnd
import matplotlib.pyplot as plt

dice_rolls = [ ]
conv_list = [ ]
sixes = 0
stop = 1

for i in range(100):
    dice_rolls.append(rnd.randint(1,6))
    if dice_rolls[i] == 6:
        sixes += 1
print(f"Percentage on 100 rolls: {100*sixes/100:.0f}%")

dice_rolls = []

for i in range(6):
    sixes = 0
    stop *= 10

    for j in range(stop):
        dice_rolls.append(rnd.randint(1,6))
        if dice_rolls[j] == 6:
            sixes+=1
    conv_list.append(sixes/stop)

conv_list

plt.plot(conv_list, "o-")
plt.grid()
plt.show()
# Out:
# Percentage on 100 rolls: 17%
